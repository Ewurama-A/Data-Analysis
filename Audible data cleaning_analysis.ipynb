# %%
# !pip install xlrd
import pandas as pd

# %%
audible = pd.read_csv(r"C:\Users\user\OneDrive\Documents\UOPEOPLE COURSES\DATA SCIENCE\Vs code programs\audible_bestsellers.csv")

audible.head()
# Out:
#   index,title,author,rating,language,release_date,runtime
# 0  0,Atomic Habits,James Clear,5.0,English\n,10-1...
# 1  1,Spare,Prince Harry The Duke of Sussex,5.0,En...
# 2  2,Daisy Jones & The Six,Taylor Jenkins Reid,4....
# 3  3,Lessons in Chemistry,Bonnie Garmus,2.0,Engli...
# 4  4,The Wedding Veil,Kristy Woodson Harvey,5.0,E...

# %%
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   index,title,author,rating,language,release_date,runtime  20 non-null     object
# dtypes: object(1)
# memory usage: 288.0+ bytes

# %%
audible[['index','title','author','rating','language','release_date','runtime']] = audible['index,title,author,rating,language,release_date,runtime'].str.split(',',n=6, expand = True)

audible.head()
# Out:
#   index,title,author,rating,language,release_date,runtime index  \
# 0  0,Atomic Habits,James Clear,5.0,English\n,10-1...          0
# 1  1,Spare,Prince Harry The Duke of Sussex,5.0,En...          1
# 2  2,Daisy Jones & The Six,Taylor Jenkins Reid,4....          2
# 3  3,Lessons in Chemistry,Bonnie Garmus,2.0,Engli...          3
# 4  4,The Wedding Veil,Kristy Woodson Harvey,5.0,E...          4
#
#                    title                           author rating   language  \
# 0          Atomic Habits                      James Clear    5.0  English\n
# 1                  Spare  Prince Harry The Duke of Sussex    5.0  English\n
# 2  Daisy Jones & The Six              Taylor Jenkins Reid    4.5  English\n
# 3   Lessons in Chemistry                    Bonnie Garmus    2.0  English\n
# 4       The Wedding Veil            Kristy Woodson Harvey    5.0  English\n
#
#   release_date              runtime
# 0   10-16-18\n    5 hrs and 35 mins
# 1   01-10-23\n   15 hrs and 39 mins
# ...

# %%
audible.drop("index,title,author,rating,language,release_date,runtime", inplace = True, axis = 1)

del audible['index']

audible
# Out:
#                                       title                           author  \
# 0                             Atomic Habits                      James Clear
# 1                                     Spare  Prince Harry The Duke of Sussex
# 2                     Daisy Jones & The Six              Taylor Jenkins Reid
# 3                      Lessons in Chemistry                    Bonnie Garmus
# 4                          The Wedding Veil            Kristy Woodson Harvey
# 5       The Subtle Art of Not Giving a F*ck                      Mark Manson
# 6                            Never Finished                    David Goggins
# 7                           It Ends with Us                   Colleen Hoover
# 8                     I\'m Glad My Mom Died                 Jennette McCurdy
# 9                     Someone Else\'s Shoes                       Jojo Moyes
# 10  "Harry Potter and the Sorcerer\'s Stone                          Book 1"
# ...

# %%
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         20 non-null     object
#  1   author        20 non-null     object
#  2   rating        20 non-null     object
#  3   language      20 non-null     object
#  4   release_date  20 non-null     object
#  5   runtime       20 non-null     object
# dtypes: object(6)
# memory usage: 1.1+ KB

# %%
audible.iloc[17, 1] = 'Jordan B. Peterson & Norman Doidge MD'


import re

audible.iloc[17,2] = audible.replace(to_replace ="'N...MD']", value = 4.5, regex = True)

audible
# Out:
#                                       title  \
# 0                             Atomic Habits
# 1                                     Spare
# 2                     Daisy Jones & The Six
# 3                      Lessons in Chemistry
# 4                          The Wedding Veil
# 5       The Subtle Art of Not Giving a F*ck
# 6                            Never Finished
# 7                           It Ends with Us
# 8                     I\'m Glad My Mom Died
# 9                     Someone Else\'s Shoes
# 10  "Harry Potter and the Sorcerer\'s Stone
# 11              Remarkably Bright Creatures
# 12                                   Verity
# 13                           Can\'t Hurt Me
# 14                         Demon Copperhead
# 15                        It Starts with Us
# 16        The Seven Husbands of Evelyn Hugo
# 17                        12 Rules for Life
# 18                              Greenlights
# 19                          8 Rules of Love
#
# ...

# %%
audible.iloc[17,2] = 4.5

audible.iloc[17,3] = 'English'

audible.iloc[17,4] = '01-23-18'

audible.iloc[17,5] = '15 hrs and 40 mins'

audible
# Out:
#                                       title  \
# 0                             Atomic Habits
# 1                                     Spare
# 2                     Daisy Jones & The Six
# 3                      Lessons in Chemistry
# 4                          The Wedding Veil
# 5       The Subtle Art of Not Giving a F*ck
# 6                            Never Finished
# 7                           It Ends with Us
# 8                     I\'m Glad My Mom Died
# 9                     Someone Else\'s Shoes
# 10  "Harry Potter and the Sorcerer\'s Stone
# 11              Remarkably Bright Creatures
# 12                                   Verity
# 13                           Can\'t Hurt Me
# 14                         Demon Copperhead
# 15                        It Starts with Us
# 16        The Seven Husbands of Evelyn Hugo
# 17                        12 Rules for Life
# 18                              Greenlights
# 19                          8 Rules of Love
#
# ...

# %%
audible.iloc[10,1] = 'J.K Rowling'
audible.iloc[10,2] = '4.5' 
audible.iloc[10,3] = 'English'
audible.iloc[10,4] = '11-20-15'
audible.iloc[10,5] = '8 hrs and 18 mins'


audible
# Out:
#                                       title  \
# 0                             Atomic Habits
# 1                                     Spare
# 2                     Daisy Jones & The Six
# 3                      Lessons in Chemistry
# 4                          The Wedding Veil
# 5       The Subtle Art of Not Giving a F*ck
# 6                            Never Finished
# 7                           It Ends with Us
# 8                     I\'m Glad My Mom Died
# 9                     Someone Else\'s Shoes
# 10  "Harry Potter and the Sorcerer\'s Stone
# 11              Remarkably Bright Creatures
# 12                                   Verity
# 13                           Can\'t Hurt Me
# 14                         Demon Copperhead
# 15                        It Starts with Us
# 16        The Seven Husbands of Evelyn Hugo
# 17                        12 Rules for Life
# 18                              Greenlights
# 19                          8 Rules of Love
#
# ...

# %%
audible['language'] = 'English'

audible
# Out:
#                                       title  \
# 0                             Atomic Habits
# 1                                     Spare
# 2                     Daisy Jones & The Six
# 3                      Lessons in Chemistry
# 4                          The Wedding Veil
# 5       The Subtle Art of Not Giving a F*ck
# 6                            Never Finished
# 7                           It Ends with Us
# 8                     I\'m Glad My Mom Died
# 9                     Someone Else\'s Shoes
# 10  "Harry Potter and the Sorcerer\'s Stone
# 11              Remarkably Bright Creatures
# 12                                   Verity
# 13                           Can\'t Hurt Me
# 14                         Demon Copperhead
# 15                        It Starts with Us
# 16        The Seven Husbands of Evelyn Hugo
# 17                        12 Rules for Life
# 18                              Greenlights
# 19                          8 Rules of Love
#
# ...

# %%
       
audible['release_date'] = audible.release_date.str.extract(r'(\d\d[-]\d\d[-]\d\d+)') 

#audible.iloc[8,0] = "I'm Glad My Mom Died"
#audible.iloc[10,0] = "Harry Potter and the Sorcerer's Stone"
#audible.iloc[13,0] = "Can't Hurt Me"
#audible.iloc[9,0] = "Someone Else's Shoes"


audible['title'] = audible.title.str.replace(r'\W', ' ')

audible
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21068\4007981328.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   audible['title'] = audible.title.str.replace(r'\W', ' ')
#                                       title  \
# 0                             Atomic Habits
# 1                                     Spare
# 2                     Daisy Jones   The Six
# 3                      Lessons in Chemistry
# 4                          The Wedding Veil
# 5       The Subtle Art of Not Giving a F ck
# 6                            Never Finished
# 7                           It Ends with Us
# 8                     I  m Glad My Mom Died
# 9                     Someone Else  s Shoes
# 10   Harry Potter and the Sorcerer  s Stone
# 11              Remarkably Bright Creatures
# 12                                   Verity
# 13                           Can  t Hurt Me
# 14                         Demon Copperhead
# ...
